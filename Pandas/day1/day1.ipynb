# %%
import pandas as pd
data=[10,20,30,40]
df=pd.Series(data,index=['a','b','c','d'],dtype='float',name="Integer Series")
print(df)
print(type(df))
# Out:
# a    10.0
# b    20.0
# c    30.0
# d    40.0
# Name: Integer Series, dtype: float64
# <class 'pandas.Series'>

# %%
data={
    "Subject":["pyhton","java","c++"],
    "Marks":[90,88,87]
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#   Subject  Marks
# 0  pyhton     90
# 1    java     88
# 2     c++     87
# <class 'pandas.DataFrame'>

# %%
import pandas as pd
data={
    "name":["puneet","naman","kartik","raaj"],
    "age":[22,21,20,21]
}
df=pd.DataFrame(data)
print(df,type(df))
print(pd.__version__)
# Out:
#      name  age
# 0  puneet   22
# 1   naman   21
# 2  kartik   20
# 3    raaj   21 <class 'pandas.DataFrame'>
# 3.0.3

# %%
import pandas as pd
data={
    "age":[22,21,20,21]}

df=pd.Series(data['age'],index=['a','b','c','d'])
print(df,['b'])
# Out:
# a    22
# b    21
# c    20
# d    21
# dtype: int64 ['b']

# %%
import pandas as pd
data={'day1':[400,500],'day2':450,'day3':430}
df=pd.Series(data)
print(df)
res=df.tolist()
print(res,type(res))
# Out:
# day1    [400, 500]
# day2           450
# day3           430
# dtype: object
# [[400, 500], 450, 430] <class 'list'>

# %%
data={
    "qmarks":[420,300,390],
    "duration":[50,40,54],
    "subject":["sub1","sub2","sub3"]
}
df=pd.DataFrame(data,index=['d1','d2','d3'])
result=df.columns
print(result)
# Out:
# Index(['qmarks', 'duration', 'subject'], dtype='str')

# %%
data={
    "qmarks":[420,300,390],
    "duration":[50,40,54],
    "subject":["sub1","sub2","sub3"]}

print(df)

df.columns=['s1','s2','s3']
print(df)
# Out:
# day1    [400, 500]
# day2           450
# day3           430
# dtype: object
# day1    [400, 500]
# day2           450
# day3           430
# dtype: object

# %%
import pandas as pd

df=pd.DataFrame([['a','b'],['c','d'],['e','f'],['g','h']],columns=['col1','col2'])
print(df)
result=df.iloc[1:3,:]
print(result)
# Out:
#   col1 col2
# 0    a    b
# 1    c    d
# 2    e    f
# 3    g    h
#   col1 col2
# 1    c    d
# 2    e    f

# %%
import pandas as pd

df=pd.DataFrame([['a','b',1,2],['c','d',34,45],['e','f',5,6],['g','h',7,8]],columns=['col1','col2','col3','col4'])
print(df)
df.index=['r1','r2','r3','r4']
result=df.loc['r1':'r4','col1':'col3']
print(result)
# Out:
#   col1 col2  col3  col4
# 0    a    b     1     2
# 1    c    d    34    45
# 2    e    f     5     6
# 3    g    h     7     8
#    col1 col2  col3
# r1    a    b     1
# r2    c    d    34
# r3    e    f     5
# r4    g    h     7

# %%
import pandas as pd

df=pd.DataFrame([['a','b',1,2],['c','d',34,45],['e','f',5,6],['g','h',7,8]],columns=['col1','col2','col3','col4'])
df.index=['r1','r2','r3','r4']
df.iloc[1:3,1]=['x','y']
print(df)
# Out:
#    col1 col2  col3  col4
# r1    a    b     1     2
# r2    c    x    34    45
# r3    e    y     5     6
# r4    g    h     7     8

# %%
import pandas as pd

df=pd.DataFrame([['a','b',1,2],['c','d',34,45],['e','f',5,6],['g','h',7,8]],columns=['col1','col2','col3','col4'])
df.index=['r1','r2','r3','r4']
df.iloc[1,2:4]=[100,77]
print(df)
# Out:
#    col1 col2  col3  col4
# r1    a    b     1     2
# r2    c    d   100    77
# r3    e    f     5     6
# r4    g    h     7     8

# %%
import pandas as pd

df=pd.DataFrame([['a','b',1,2],['c','d',34,45],['e','f',5,6],['g','h',7,8]],columns=['col1','col2','col3','col4'])
df.index=['r1','r2','r3','r4']
print(df)
print(df.loc["r2"])
res=df.drop('r1')
print(res)
# Out:
#    col1 col2  col3  col4
# r1    a    b     1     2
# r2    c    d    34    45
# r3    e    f     5     6
# r4    g    h     7     8
# col1     c
# col2     d
# col3    34
# col4    45
# Name: r2, dtype: object
#    col1 col2  col3  col4
# r2    c    d    34    45
# r3    e    f     5     6
# r4    g    h     7     8

# %%
import pandas as pd

df=pd.DataFrame([['a','b',1,2],['c','d',34,45],['e','f',5,6],['g','h',7,0]],columns=['col1','col2','col3','col4'])
df.index=['r1','r2','r3','r4']
print(df)
res=df[df['col4']!=0]
print(res)
# Out:
#    col1 col2  col3  col4
# r1    a    b     1     2
# r2    c    d    34    45
# r3    e    f     5     6
# r4    g    h     7     0
#    col1 col2  col3  col4
# r1    a    b     1     2
# r2    c    d    34    45
# r3    e    f     5     6

# %%
import pandas as pd

df=pd.DataFrame([['a','b',1,2],['c','d',34,45],['e','f',5,6],['g','h',7,8]],columns=['col1','col2','col3','col4'])
df.index=['r1','r2','r3','r4']
print(df)
res=df.drop(df.index[1:2])
print(res)
# Out:
#    col1 col2  col3  col4
# r1    a    b     1     2
# r2    c    d    34    45
# r3    e    f     5     6
# r4    g    h     7     8
#    col1 col2  col3  col4
# r1    a    b     1     2
# r3    e    f     5     6
# r4    g    h     7     8

# %%
import pandas as pd

df=pd.DataFrame([['a','b',1,2],['c','d',34,45],['e','f',5,6],['g','h',7,8]],columns=['col1','col2','col3','col4'])
df.index=['r1','r2','r3','r4']
print(df)
res=df.drop(columns=['col2','col4'])
print(res)
# Out:
#    col1 col2  col3  col4
# r1    a    b     1     2
# r2    c    d    34    45
# r3    e    f     5     6
# r4    g    h     7     8
#    col1  col3
# r1    a     1
# r2    c    34
# r3    e     5
# r4    g     7
