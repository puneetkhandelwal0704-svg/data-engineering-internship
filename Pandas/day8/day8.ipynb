# %%
import greet
greet.greeting("python")
# Out:
# hello python

# %%
import pymath

pymath.sum(4,6)
# Out:
# 10

# %%
import platform
x=platform.system()
y=dir(platform)
print(x)
print(y)
# Out:
# Windows
# ...

# %%
import math

print(acos(0))
print(math.factorial(7))
print(math.pow(9,3))
# Out:
# 1.5707963267948966
# 5040
# 729.0

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
import datetime 
x=datetime.datetime(2026,6,2)
print(x)
print(x.year)
# Out:
# 2026-06-02 00:00:00
# 2026

# %%
x=datetime.datetime.now()
print(x.strftime("%B"))
# Out:
# June

# %%
import random
cnum=random.randrange(0,100)
unum=int(input("enter the number:"))
if cnum>unum:
    print("computer number:",cnum,"is greater")
elif unum>cnum:
    print("computer number:",unum,"is smaller")
else:
    print("computer number:",cnum,"is equal")
# Out:
# computer number: 90 is greater

# %%
import os
os.chdir()

# %%
import qrcode
data='https://www.coplur.com/home'
img=qrcode.make(data)
img.save('qr1.png')

# %%
import cv2
image = cv2.imread("qr1.png")
detector = cv2. QRCodeDetector()
data, vertices_array, binary_qrcode = detector.detectAndDecode (image)
if vertices_array is not None and data:
       print(f"QR Data: {data}")
else:
        print("No Data Found.")
# Out:
# QR Data: https://www.coplur.com/home

# %%
import
